# %%
# Time Series Forecasting Pipeline - SageMaker Demo 🚀

## Cross-Market Predictive Analytics with Regime Detection

This notebook demonstrates the complete pipeline for time series forecasting with cross-market analysis and regime detection.

### What you'll learn:
- How to collect financial data from multiple markets
- Feature engineering for time series analysis
- Market regime detection using machine learning
- Cross-market predictive modeling
- Model evaluation and interpretation

# %%
# Install required packages
# !pip install yfinance xgboost ta tensorflow scikit-learn statsmodels boto3 sagemaker

# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Set up plotting
plt.style.use('seaborn-v0_8')
plt.rcParams['figure.figsize'] = (12, 8)

print("✅ Setup completed successfully!")

# %%
## 🎯 Run Complete Pipeline (Recommended)

This is the simplest way to run the entire project:

# %%
# Run the complete pipeline
exec(open('main_pipeline.py').read())

print("🎉 Pipeline completed! Check the results/ directory for outputs.")
